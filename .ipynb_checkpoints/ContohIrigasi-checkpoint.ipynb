 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [67, 56], [68, 56], [68, 56], [68, 56], [68, 56], [68, 56], [68, 56], [68, 57], [68, 57], [68, 57], [68, 57], [68, 57], [68, 57], [68, 57], [68, 57], [68, 57], [68, 57], [68, 57], [68, 57], [69, 57], [69, 57], ...

# %%
df.describe()

# %%
yd =[]
for xd in y:
    yd.append(xd[['humidity','temperature',
                'ambient humidity','ambient temperature',
                  'light']].diff().fillna(0))
dfdiff = pd.concat(yd)

# %%
df['status'].unique()

# %%
dfdiff.describe()

# %%
print(df.columns)

# %%
data = df[['humidity', 'temperature', 'ambient humidity',
       'ambient temperature', 'light']].to_numpy()

# %%
label = df['status'].to_numpy()

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(data, label, test_size=0.10, random_state=42)

# %%
from sklearn import svm
clf = svm.SVC(gamma='scale')
clf.fit(train_x,train_y)

# %%
pred_y = clf.predict(test_x)
from sklearn.metrics import accuracy_score
score = accuracy_score(test_y,pred_y)
print(score)

# %%
datad = dfdiff[['humidity', 'temperature', 'ambient humidity',
       'ambient temperature', 'light']].to_numpy()

# %%
labeld = df['status'].to_numpy()

# %%
train_x, test_x, train_y, test_y = train_test_split(datad, labeld, test_size=0.10, random_state=42)

# %%
clf = svm.SVC(kernel='linear')
clf.fit(train_x,train_y)

# %%
pred_y = clf.predict(test_x)
from sklearn.metrics import accuracy_score
score = accuracy_score(test_y,pred_y)
print(score)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import svm
import numpy as np
from sklearn.inspection import DecisionBoundaryDisplay

X = df[['humidity','temperature']].to_numpy()
y = df['status'].map({'siram': 0,
                      'mengering': 1})
    
clf = svm.SVC(kernel='linear')
clf.fit(X, y)
plt.scatter(X[:,0],X[:,1],c=y,s=30,cmap=plt.cm.Paired)

ax = plt.gca()
DecisionBoundaryDisplay.from_estimator(
    clf,
    X,
    plot_method="contour",
    colors="k",
    levels=[-1, 0, 1],
    alpha=0.5,
    linestyles=["--", "-", "--"],
    ax=ax,
)
# plot support vectors
ax.scatter(
    clf.support_vectors_[:, 0],
    clf.support_vectors_[:, 1],
    s=100,
    linewidth=1,
    facecolors="none",
    edgecolors="k",
)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import svm
import numpy as np
from sklearn.inspection import DecisionBoundaryDisplay

X = dfdiff[['humidity','temperature']].to_numpy()
y = df['status'].map({'siram': 0,
                      'mengering': 1})
    
clf = svm.SVC()
clf.fit(X, y)
plt.scatter(X[:,0],X[:,1],c=y,s=30,cmap=plt.cm.Paired)

ax = plt.gca()
DecisionBoundaryDisplay.from_estimator(
    clf,
    X,
    plot_method="contour",
    colors="k",
    levels=[-1, 0, 1],
    alpha=0.5,
    linestyles=["--", "-", "--"],
    ax=ax,
)
# plot support vectors
ax.scatter(
    clf.support_vectors_[:, 0],
    clf.support_vectors_[:, 1],
    s=100,
    linewidth=1,
    facecolors="none",
    edgecolors="k",
)
plt.show()
